# %% [markdown]
# # Asset Portfolio Management using Deep Reinforcement Learning
# ---

# %% [markdown]
# ## 6.0 Deep Reinforcement Learning Portfolio without transaction costs

# %% [markdown]
# ### 6.1 Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt
matplotlib.use('Agg')
import datetime
from pypfopt import EfficientFrontier, objective_functions
from pypfopt import risk_models
from pypfopt import expected_returns
from gym.utils import seeding
import gym
from gym import spaces
matplotlib.use('Agg')
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
#pip install shimmy

# %%
#pip install stockstats

# %%
#pip install exchange-calendars

# %%
#pip install wrds

# %% [markdown]
# ### 6.2 Load Data

# %%
train_data = pd.read_csv('./datasets/train_data.csv')
test_data = pd.read_csv('./datasets/test_data.csv')

# %%
tech_indicator_list = ["open", "high", "low", "close", "volume", "atr", "sma", "rsi", "oil_chg", 'yield_chg']

# %%
#train_data

# %% [markdown]
# ### 6.3 Implement DRL

# %%
import importlib
import my_env
from my_env import StockPortfolioEnv
import gym

# %%
import my_models
from my_models import DRLAgent

# %%
stock_dimension = len(train_data.tic.unique())
state_space = stock_dimension

# %%
weights_initial = [1/stock_dimension]*stock_dimension

# %%
env_kwargs = { 
    "hmax": 500, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0, 
    "state_space": 15, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicator_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 1,
    'initial_weights': [1/stock_dimension]*stock_dimension
}

# %%
#print(train_data.dtypes)

# %%
#train_data

# %%
#train_data['date'] = pd.to_datetime(train_data['date'], errors='coerce')
#train_data['date'] = train_data['date'].map(pd.Timestamp.timestamp).astype('float64')
#train_data['tic'] = train_data['tic'].astype('category').cat.codes.astype('float64')
#train_data['obv'] = train_data['obv'].astype('float64')
#train_data['volume'] = train_data['volume'].astype('float64')
#print(train_data.dtypes)

# %%
e_train_gym = StockPortfolioEnv(df = train_data, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# F:\Anaconda\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
real_env = env_train.envs[0]    # <-- This is your actual StockPortfolioEnv instance
#print("Shape of self.data.close:", real_env.data.close.shape)
#print("Shape of self.action space:", real_env.action_space.shape)
#print("Shape of self.state", real_env.state.shape)
#print("Length of date_memory:", len(real_env.date_memory))
#print(real_env.data['date'].iloc[0])  # Should print the first date
#print("Length of actions_memory:", len(real_env.actions_memory))
#actions = real_env.actions_memory[-1]  # Replace this with how you're storing actions
#weights = real_env.softmax_normalization(actions)
#print("Shape of weights:", weights.shape)
#print("Weights:", weights)

# %%
#real_env.data

# %%
#real_env.df

# %%
#real_env.data.close

# %% [markdown]
# #### 6.3.1 Model: A2C

# %%
# initialize
agent = DRLAgent(env = env_train)

#A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
A2C_PARAMS = {
    "n_steps": 10,  # Number of steps to roll out the environment
    "gamma": 0.95,  # Discount factor
    "learning_rate": 0.0002,  # Learning rate for the optimizer
    "ent_coef": 0.01,  # Entropy coefficient for exploration
    "vf_coef": 0.5,  # Value function coefficient
    "max_grad_norm": 0.3,  # Maximum norm for gradient clipping
}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 10, 'gamma': 0.95, 'learning_rate': 0.0002, 'ent_coef': 0.01, 'vf_coef': 0.5, 'max_grad_norm': 0.3}
# Using cpu device

# %%
from stable_baselines3.common.callbacks import BaseCallback
import matplotlib.pyplot as plt
import os

class PortfolioMonitorCallback(BaseCallback):
    """
    Custom callback for tracking environment rewards (portfolio rewards)
    and cumulative rewards during training in Jupyter.
    It saves both reward and cumulative reward plots to disk.
    """
    def __init__(self, verbose=0):
        super(PortfolioMonitorCallback, self).__init__(verbose)
        self.portfolio_rewards = []  # To store step-by-step rewards
        self.cumulative_rewards = []  # To store cumulative rewards
        self.cumulative_reward = 0.0  # Running total for cumulative rewards
        os.makedirs("results", exist_ok=True)  # Ensure "results/" folder exists

    def _on_step(self) -> bool:
        # self.model.env is a VecEnv, so the actual env is self.model.env.envs[0]
        env = self.model.env.envs[0]
        
        step_reward = env.reward
        self.portfolio_rewards.append(step_reward)
        
        self.cumulative_reward += step_reward
        self.cumulative_rewards.append(self.cumulative_reward)
        
        return True  # Return False to stop training early if needed

    def _on_training_end(self) -> None:
        # Plot the reward curve
        plt.figure(figsize=(8,4))
        plt.plot(self.portfolio_rewards, label="Portfolio Reward", color='green',linewidth=0.1)
        plt.xlabel("Time Step")
        plt.ylabel("Reward")
        plt.legend()
        plt.savefig("results/portfolio_rewards.png")  # Save reward plot to disk
        plt.close()

        plt.figure(figsize=(8,4))
        plt.plot(self.cumulative_rewards, label="Cumulative Reward", color='green')
        plt.xlabel("Time Step")
        plt.ylabel("Cumulative Reward")
        plt.legend()
        plt.savefig("results/cumulative_rewards.png")  # Save cumulative reward plot to disk
        plt.close()

# %%
model_a2c = agent.get_model(model_name="a2c", model_kwargs=A2C_PARAMS)

monitor_callback = PortfolioMonitorCallback()

trained_a2c = agent.train_model(
    model=model_a2c,
    tb_log_name='a2c',
    total_timesteps=100000,
    log_interval=10,
    callback=monitor_callback
)
# Out:
# {'n_steps': 10, 'gamma': 0.95, 'learning_rate': 0.0002, 'ent_coef': 0.01, 'vf_coef': 0.5, 'max_grad_norm': 0.3}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_415
# ------------------------------------
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 10       |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 100      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -267     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9        |
# |    policy_loss        | -1.54    |
# |    std                | 1        |
# |    value_loss         | 0.141    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 20       |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 200      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -39.2    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 19       |
# |    policy_loss        | 0.865    |
# |    std                | 1        |
# |    value_loss         | 0.175    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 30       |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 300      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -30.6    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 29       |
# |    policy_loss        | -0.698   |
# |    std                | 1        |
# |    value_loss         | 0.0256   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 40       |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 400      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -13.4    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 39       |
# |    policy_loss        | 0.193    |
# |    std                | 1        |
# |    value_loss         | 0.0523   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 50       |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -399     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 49       |
# |    policy_loss        | -5.91    |
# |    std                | 1        |
# |    value_loss         | 0.201    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 60       |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 600      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -63.7    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 59       |
# |    policy_loss        | -1.15    |
# |    std                | 1        |
# |    value_loss         | 0.0577   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 70       |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 700      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -555     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 69       |
# |    policy_loss        | 0.831    |
# |    std                | 1        |
# |    value_loss         | 0.0567   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 80       |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 800      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -49.2    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 79       |
# |    policy_loss        | 3.79     |
# |    std                | 1        |
# |    value_loss         | 0.149    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 90       |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 900      |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -54.9    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 89       |
# |    policy_loss        | 0.651    |
# |    std                | 1        |
# |    value_loss         | 0.066    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 100      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -48.1    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 99       |
# |    policy_loss        | 2.16     |
# |    std                | 1        |
# |    value_loss         | 0.136    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 110      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1100     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -32.6    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 109      |
# |    policy_loss        | -1.6     |
# |    std                | 1        |
# |    value_loss         | 0.0492   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 120      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1200     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -81.9    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 119      |
# |    policy_loss        | -0.529   |
# |    std                | 1        |
# |    value_loss         | 0.0643   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 130      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1300     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -31.3    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 129      |
# |    policy_loss        | 3.02     |
# |    std                | 1        |
# |    value_loss         | 0.0743   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 140      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1400     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -15.9    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 139      |
# |    policy_loss        | 1.16     |
# |    std                | 1        |
# |    value_loss         | 0.0348   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 150      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -33.6    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 149      |
# |    policy_loss        | 4.16     |
# |    std                | 1        |
# |    value_loss         | 0.107    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 160      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1600     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -7.72    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 159      |
# |    policy_loss        | 1.36     |
# |    std                | 1        |
# |    value_loss         | 0.0144   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 170      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 1700     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -296     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 169      |
# |    policy_loss        | -1.38    |
# |    std                | 1        |
# |    value_loss         | 0.0354   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 180      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 1800     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -6.59    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 179      |
# |    policy_loss        | 0.351    |
# |    std                | 1        |
# |    value_loss         | 0.0136   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 190      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 1900     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -102     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 189      |
# |    policy_loss        | -1.2     |
# |    std                | 1        |
# |    value_loss         | 0.018    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 200      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -62      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 199      |
# |    policy_loss        | 2.18     |
# |    std                | 1.01     |
# |    value_loss         | 0.0788   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 210      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 2100     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -5.03    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 209      |
# |    policy_loss        | -0.311   |
# |    std                | 1.01     |
# |    value_loss         | 0.0171   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 220      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 2200     |
# | train/                |          |
# |    entropy_loss       | -14.2    |
# |    explained_variance | -97.6    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 219      |
# |    policy_loss        | -1.87    |
# |    std                | 1.01     |
# |    value_loss         | 0.0303   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 230      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2300     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -444     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 229      |
# |    policy_loss        | -1.18    |
# |    std                | 1.01     |
# |    value_loss         | 0.0746   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 240      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2400     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -41.1    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 239      |
# |    policy_loss        | -0.81    |
# |    std                | 1.01     |
# |    value_loss         | 0.0425   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 250      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -194     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 249      |
# |    policy_loss        | -0.919   |
# |    std                | 1.01     |
# |    value_loss         | 0.0365   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 260      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 2600     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -310     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 259      |
# |    policy_loss        | -0.422   |
# |    std                | 1.01     |
# |    value_loss         | 0.0171   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 270      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 2700     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -62.6    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 269      |
# |    policy_loss        | 1.98     |
# |    std                | 1.01     |
# |    value_loss         | 0.0536   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 280      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 2800     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -160     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 279      |
# |    policy_loss        | 0.782    |
# |    std                | 1.01     |
# |    value_loss         | 0.0698   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 290      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 2900     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -14      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 289      |
# |    policy_loss        | 2.76     |
# |    std                | 1.01     |
# |    value_loss         | 0.0507   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 300      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -0.888   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.845   |
# |    std                | 1.01     |
# |    value_loss         | 0.00626  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 310      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 3100     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -242     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 309      |
# |    policy_loss        | 1.21     |
# |    std                | 1.01     |
# |    value_loss         | 0.0145   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 320      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 3200     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -22      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 319      |
# |    policy_loss        | 1.05     |
# |    std                | 1.01     |
# |    value_loss         | 0.0109   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 330      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 3300     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -9       |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 329      |
# |    policy_loss        | -1.2     |
# |    std                | 1.01     |
# |    value_loss         | 0.0168   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 340      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3400     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -11.1    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 339      |
# |    policy_loss        | 1.39     |
# |    std                | 1.01     |
# |    value_loss         | 0.0189   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 350      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -10.3    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 349      |
# |    policy_loss        | 1.66     |
# |    std                | 1.01     |
# |    value_loss         | 0.0173   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 360      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 3600     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -1.48    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 359      |
# |    policy_loss        | -1.72    |
# |    std                | 1.01     |
# |    value_loss         | 0.0199   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 370      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 3700     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -0.527   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 369      |
# |    policy_loss        | -1.64    |
# |    std                | 1.01     |
# |    value_loss         | 0.0162   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 380      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 3800     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -4.48    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 379      |
# |    policy_loss        | 0.448    |
# |    std                | 1.01     |
# |    value_loss         | 0.00232  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 390      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 3900     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -0.0921  |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 389      |
# |    policy_loss        | -0.568   |
# |    std                | 1.01     |
# |    value_loss         | 0.00214  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 400      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -51.3    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.884    |
# |    std                | 1.01     |
# |    value_loss         | 0.0194   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 410      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 4100     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -265     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 409      |
# |    policy_loss        | 0.808    |
# |    std                | 1.02     |
# |    value_loss         | 0.047    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 420      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 4200     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -16.1    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 419      |
# |    policy_loss        | -1.15    |
# |    std                | 1.02     |
# |    value_loss         | 0.0269   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 430      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 4300     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -57.8    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 429      |
# |    policy_loss        | -1.45    |
# |    std                | 1.02     |
# |    value_loss         | 0.0264   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 440      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 4400     |
# | train/                |          |
# |    entropy_loss       | -14.3    |
# |    explained_variance | -20      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 439      |
# |    policy_loss        | 2.94     |
# |    std                | 1.02     |
# |    value_loss         | 0.0609   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 450      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -19.5    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 449      |
# |    policy_loss        | -2.19    |
# |    std                | 1.02     |
# |    value_loss         | 0.0345   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 460      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 4600     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -9.15    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 459      |
# |    policy_loss        | 0.893    |
# |    std                | 1.02     |
# |    value_loss         | 0.0103   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 470      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 4700     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -255     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 469      |
# |    policy_loss        | -1.13    |
# |    std                | 1.02     |
# |    value_loss         | 0.0183   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 480      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 4800     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -13.3    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 479      |
# |    policy_loss        | -0.139   |
# |    std                | 1.02     |
# |    value_loss         | 0.0161   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 233      |
# |    iterations         | 490      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 4900     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -8.39    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 489      |
# |    policy_loss        | -0.0553  |
# |    std                | 1.02     |
# |    value_loss         | 0.00541  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 232      |
# |    iterations         | 500      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -34.6    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.557    |
# |    std                | 1.02     |
# |    value_loss         | 0.00588  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 231      |
# |    iterations         | 510      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5100     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -38.2    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 509      |
# |    policy_loss        | -1.95    |
# |    std                | 1.02     |
# |    value_loss         | 0.0272   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 231      |
# |    iterations         | 520      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5200     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -0.257   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 519      |
# |    policy_loss        | -2.21    |
# |    std                | 1.02     |
# |    value_loss         | 0.0391   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 231      |
# |    iterations         | 530      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5300     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -217     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 529      |
# |    policy_loss        | 1.31     |
# |    std                | 1.02     |
# |    value_loss         | 0.0287   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 232      |
# |    iterations         | 540      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5400     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -108     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 539      |
# |    policy_loss        | 0.349    |
# |    std                | 1.02     |
# |    value_loss         | 0.0203   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 232      |
# |    iterations         | 550      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -13.1    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 549      |
# |    policy_loss        | -1.07    |
# |    std                | 1.02     |
# |    value_loss         | 0.0083   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 233      |
# |    iterations         | 560      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 5600     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -0.638   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 559      |
# |    policy_loss        | -1.57    |
# |    std                | 1.02     |
# |    value_loss         | 0.0129   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 233      |
# |    iterations         | 570      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 5700     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -1.39    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 569      |
# |    policy_loss        | -0.376   |
# |    std                | 1.02     |
# |    value_loss         | 0.0011   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 233      |
# |    iterations         | 580      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 5800     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -3.15    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 579      |
# |    policy_loss        | -0.0923  |
# |    std                | 1.02     |
# |    value_loss         | 0.000616 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 234      |
# |    iterations         | 590      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 5900     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -1.34    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 589      |
# |    policy_loss        | 1.98     |
# |    std                | 1.02     |
# |    value_loss         | 0.02     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 234      |
# |    iterations         | 600      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -24.5    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 599      |
# |    policy_loss        | 2.16     |
# |    std                | 1.02     |
# |    value_loss         | 0.0283   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 610      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 6100     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -3.9     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 609      |
# |    policy_loss        | 5.27     |
# |    std                | 1.02     |
# |    value_loss         | 0.14     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 620      |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 6200     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -10.7    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 619      |
# |    policy_loss        | -0.817   |
# |    std                | 1.02     |
# |    value_loss         | 0.00811  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 630      |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 6300     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -9.97    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 629      |
# |    policy_loss        | 0.35     |
# |    std                | 1.02     |
# |    value_loss         | 0.00927  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 640      |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 6400     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -2.41    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 639      |
# |    policy_loss        | 7.18     |
# |    std                | 1.02     |
# |    value_loss         | 0.24     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 650      |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -233     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 649      |
# |    policy_loss        | -0.301   |
# |    std                | 1.02     |
# |    value_loss         | 0.0153   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 660      |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 6600     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -10.1    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 659      |
# |    policy_loss        | -0.0691  |
# |    std                | 1.03     |
# |    value_loss         | 0.00454  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 670      |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 6700     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -32.9    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 669      |
# |    policy_loss        | 1.49     |
# |    std                | 1.03     |
# |    value_loss         | 0.0156   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 680      |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 6800     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -26.3    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 679      |
# |    policy_loss        | 2.12     |
# |    std                | 1.03     |
# |    value_loss         | 0.0253   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 690      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 6900     |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | -44.1    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 689      |
# |    policy_loss        | -0.51    |
# |    std                | 1.03     |
# |    value_loss         | 0.00567  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 700      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -25.3    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.541    |
# |    std                | 1.03     |
# |    value_loss         | 0.00444  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 710      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 7100     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -27      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 709      |
# |    policy_loss        | 0.383    |
# |    std                | 1.03     |
# |    value_loss         | 0.00219  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 720      |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 7200     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -19.6    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 719      |
# |    policy_loss        | 1.51     |
# |    std                | 1.03     |
# |    value_loss         | 0.0273   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 730      |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 7300     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -13.2    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 729      |
# |    policy_loss        | 0.67     |
# |    std                | 1.03     |
# |    value_loss         | 0.0058   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 740      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 7400     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -13.2    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 739      |
# |    policy_loss        | 0.603    |
# |    std                | 1.03     |
# |    value_loss         | 0.0042   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 750      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -21.6    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 749      |
# |    policy_loss        | 0.123    |
# |    std                | 1.03     |
# |    value_loss         | 0.00781  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 760      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 7600     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -176     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 759      |
# |    policy_loss        | 0.309    |
# |    std                | 1.03     |
# |    value_loss         | 0.00822  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 770      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 7700     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -47.2    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 769      |
# |    policy_loss        | 0.489    |
# |    std                | 1.03     |
# |    value_loss         | 0.00714  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 780      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 7800     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -0.531   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 779      |
# |    policy_loss        | 0.924    |
# |    std                | 1.03     |
# |    value_loss         | 0.00636  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 790      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 7900     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -27.1    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 789      |
# |    policy_loss        | -0.246   |
# |    std                | 1.03     |
# |    value_loss         | 0.0103   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 800      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -61.4    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.227   |
# |    std                | 1.03     |
# |    value_loss         | 0.0344   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 810      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 8100     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -201     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 809      |
# |    policy_loss        | -0.457   |
# |    std                | 1.03     |
# |    value_loss         | 0.0169   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 820      |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 8200     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -23.2    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 819      |
# |    policy_loss        | -0.336   |
# |    std                | 1.03     |
# |    value_loss         | 0.00383  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 830      |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 8300     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -0.568   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 829      |
# |    policy_loss        | 0.919    |
# |    std                | 1.04     |
# |    value_loss         | 0.00461  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 840      |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 8400     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -44.9    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 839      |
# |    policy_loss        | 0.9      |
# |    std                | 1.04     |
# |    value_loss         | 0.0085   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 850      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -59.5    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 849      |
# |    policy_loss        | -0.464   |
# |    std                | 1.04     |
# |    value_loss         | 0.016    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 860      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 8600     |
# | train/                |          |
# |    entropy_loss       | -14.5    |
# |    explained_variance | -12.9    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 859      |
# |    policy_loss        | 0.851    |
# |    std                | 1.04     |
# |    value_loss         | 0.00659  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# ...
# |    iterations         | 9720     |
# |    time_elapsed       | 372      |
# |    total_timesteps    | 97200    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -1.28    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9719     |
# |    policy_loss        | -0.131   |
# |    std                | 2.33     |
# |    value_loss         | 0.000441 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9730     |
# |    time_elapsed       | 372      |
# |    total_timesteps    | 97300    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -0.751   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9729     |
# |    policy_loss        | 1.11     |
# |    std                | 2.33     |
# |    value_loss         | 0.00363  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9740     |
# |    time_elapsed       | 372      |
# |    total_timesteps    | 97400    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -4.23    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9739     |
# |    policy_loss        | -0.0424  |
# |    std                | 2.34     |
# |    value_loss         | 0.000639 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9750     |
# |    time_elapsed       | 373      |
# |    total_timesteps    | 97500    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -3.18    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9749     |
# |    policy_loss        | 0.65     |
# |    std                | 2.34     |
# |    value_loss         | 0.00152  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9760     |
# |    time_elapsed       | 373      |
# |    total_timesteps    | 97600    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -3.44    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9759     |
# |    policy_loss        | 0.02     |
# |    std                | 2.34     |
# |    value_loss         | 0.000235 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9770     |
# |    time_elapsed       | 373      |
# |    total_timesteps    | 97700    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -2.62    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9769     |
# |    policy_loss        | -0.111   |
# |    std                | 2.34     |
# |    value_loss         | 0.000254 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9780     |
# |    time_elapsed       | 374      |
# |    total_timesteps    | 97800    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -0.283   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9779     |
# |    policy_loss        | -1.43    |
# |    std                | 2.35     |
# |    value_loss         | 0.00705  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9790     |
# |    time_elapsed       | 374      |
# |    total_timesteps    | 97900    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -0.661   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9789     |
# |    policy_loss        | 0.528    |
# |    std                | 2.35     |
# |    value_loss         | 0.00088  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9800     |
# |    time_elapsed       | 375      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -22.7    |
# |    explained_variance | -1.44    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9799     |
# |    policy_loss        | -0.586   |
# |    std                | 2.35     |
# |    value_loss         | 0.000943 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9810     |
# |    time_elapsed       | 375      |
# |    total_timesteps    | 98100    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -2.05    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9809     |
# |    policy_loss        | -0.666   |
# |    std                | 2.35     |
# |    value_loss         | 0.00197  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9820     |
# |    time_elapsed       | 376      |
# |    total_timesteps    | 98200    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -2.19    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9819     |
# |    policy_loss        | 0.00757  |
# |    std                | 2.36     |
# |    value_loss         | 0.00108  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9830     |
# |    time_elapsed       | 376      |
# |    total_timesteps    | 98300    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -1.95    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9829     |
# |    policy_loss        | -0.248   |
# |    std                | 2.36     |
# |    value_loss         | 0.000263 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9840     |
# |    time_elapsed       | 376      |
# |    total_timesteps    | 98400    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -0.866   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9839     |
# |    policy_loss        | 0.152    |
# |    std                | 2.36     |
# |    value_loss         | 0.00044  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9850     |
# |    time_elapsed       | 377      |
# |    total_timesteps    | 98500    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -3.72    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9849     |
# |    policy_loss        | 0.746    |
# |    std                | 2.37     |
# |    value_loss         | 0.00128  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9860     |
# |    time_elapsed       | 377      |
# |    total_timesteps    | 98600    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -8.04    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9859     |
# |    policy_loss        | 0.747    |
# |    std                | 2.37     |
# |    value_loss         | 0.00181  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9870     |
# |    time_elapsed       | 377      |
# |    total_timesteps    | 98700    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -1.37    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9869     |
# |    policy_loss        | 0.407    |
# |    std                | 2.37     |
# |    value_loss         | 0.00046  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9880     |
# |    time_elapsed       | 378      |
# |    total_timesteps    | 98800    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -3.27    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9879     |
# |    policy_loss        | -0.385   |
# |    std                | 2.37     |
# |    value_loss         | 0.000488 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9890     |
# |    time_elapsed       | 378      |
# |    total_timesteps    | 98900    |
# | train/                |          |
# |    entropy_loss       | -22.8    |
# |    explained_variance | -8.41    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9889     |
# |    policy_loss        | 0.315    |
# |    std                | 2.38     |
# |    value_loss         | 0.00303  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9900     |
# |    time_elapsed       | 378      |
# |    total_timesteps    | 99000    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -0.34    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9899     |
# |    policy_loss        | 0.3      |
# |    std                | 2.38     |
# |    value_loss         | 0.000312 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9910     |
# |    time_elapsed       | 379      |
# |    total_timesteps    | 99100    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -0.0455  |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9909     |
# |    policy_loss        | -0.299   |
# |    std                | 2.38     |
# |    value_loss         | 0.000216 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9920     |
# |    time_elapsed       | 379      |
# |    total_timesteps    | 99200    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -2.72    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9919     |
# |    policy_loss        | 0.107    |
# |    std                | 2.38     |
# |    value_loss         | 0.000418 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9930     |
# |    time_elapsed       | 380      |
# |    total_timesteps    | 99300    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -9.5     |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9929     |
# |    policy_loss        | -0.54    |
# |    std                | 2.39     |
# |    value_loss         | 0.00195  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9940     |
# |    time_elapsed       | 380      |
# |    total_timesteps    | 99400    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -0.355   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9939     |
# |    policy_loss        | 0.304    |
# |    std                | 2.39     |
# |    value_loss         | 0.00109  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9950     |
# |    time_elapsed       | 380      |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -0.299   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9949     |
# |    policy_loss        | 0.407    |
# |    std                | 2.39     |
# |    value_loss         | 0.000534 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9960     |
# |    time_elapsed       | 381      |
# |    total_timesteps    | 99600    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -0.24    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9959     |
# |    policy_loss        | -0.832   |
# |    std                | 2.39     |
# |    value_loss         | 0.00151  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9970     |
# |    time_elapsed       | 381      |
# |    total_timesteps    | 99700    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -0.592   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9969     |
# |    policy_loss        | 0.211    |
# |    std                | 2.4      |
# |    value_loss         | 0.000384 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9980     |
# |    time_elapsed       | 381      |
# |    total_timesteps    | 99800    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -0.193   |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9979     |
# |    policy_loss        | 0.217    |
# |    std                | 2.4      |
# |    value_loss         | 0.000443 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 9990     |
# |    time_elapsed       | 382      |
# |    total_timesteps    | 99900    |
# | train/                |          |
# |    entropy_loss       | -22.9    |
# |    explained_variance | -3.85    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9989     |
# |    policy_loss        | 0.271    |
# |    std                | 2.4      |
# |    value_loss         | 0.00033  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 10000    |
# |    time_elapsed       | 382      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -23      |
# |    explained_variance | -5.88    |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9999     |
# |    policy_loss        | -0.549   |
# |    std                | 2.4      |
# |    value_loss         | 0.000978 |
# ------------------------------------

# %%
# %load_ext tensorboard
# %tensorboard --logdir tensorboard_log
#%tensorboard --logdir tensorboard_log/a2c --host localhost --port 6007
#%tensorboard --logdir=tensorboard_log/a2c --host 0.0.0.0 --port 6008
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 23920), started 4 days, 4:36:46 ago. (Use '!kill 23920' to kill it.)
#       <iframe id="tensorboard-frame-44950c70f8578ee6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-44950c70f8578ee6");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### 8.5 Backtesting

# %%
#A2C
e_trade_gym = StockPortfolioEnv(df = test_data, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_test_daily_return, a2c_test_weights = DRLAgent.DRL_prediction(model=trained_a2c,
                        test_data = test_data,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# F:\Anaconda\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
a2c_test_weights.to_csv('weights/a2c_test_weights.csv')

# %%
a2c_test_weights
# Out:
# tic            BOREO     ELISA     ICP1V     MEKKO    NDA-FI     NESTE  \
# date
# 2023-01-03  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 2023-01-04  0.230318  0.000000  0.230318  0.002210  0.230318  0.000000
# 2023-01-05  0.267989  0.091622  0.000000  0.000000  0.267989  0.104412
# 2023-01-09  0.036414  0.183312  0.000000  0.074548  0.000000  0.183312
# 2023-01-10  0.256263  0.000000  0.236219  0.256263  0.000000  0.242695
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-19  0.200000  0.000000  0.200000  0.200000  0.200000  0.000000
# 2024-12-20  0.000000  0.334561  0.000000  0.000000  0.330877  0.000000
# 2024-12-23  0.250000  0.250000  0.250000  0.000000  0.250000  0.000000
# 2024-12-27  0.226167  0.226167  0.000000  0.000000  0.226167  0.000000
# 2024-12-30  0.219263  0.000000  0.219263  0.000000  0.219263  0.000000
#
# tic            OLVAS     SAMPO       UPM       YIT
# date
# 2023-01-03  0.100000  0.100000  0.100000  0.100000
# 2023-01-04  0.230318  0.000000  0.076519  0.000000
# 2023-01-05  0.000000  0.000000  0.000000  0.267989
# 2023-01-09  0.000000  0.155788  0.183312  0.183312
# 2023-01-10  0.008560  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...
# 2024-12-19  0.000000  0.000000  0.000000  0.200000
# 2024-12-20  0.334561  0.000000  0.000000  0.000000
# 2024-12-23  0.000000  0.000000  0.000000  0.000000
# 2024-12-27  0.095331  0.226167  0.000000  0.000000
# 2024-12-30  0.000000  0.219263  0.122949  0.000000
#
# [487 rows x 10 columns]

# %% [markdown]
# ### 8.6 Save the Portfolios

# %%
a2c_test_daily_return.to_csv('datasets/a2c_test_daily_return.csv', index=False)
